# %%
import spacy
from nltk.stem import WordNetLemmatizer

# %%
with open('ban') as data_file:
        sentences = data_file.readlines()

# %%
nlp = spacy.load('en_core_web_lg')
wordnet_lemmatizer = WordNetLemmatizer()

# %%
sentences
# Out:
# ["Referee banned for using 'rock, paper, scissors' to decide kickoff\n",
#  'Smith, Warner bans will stand: CA chief ahead of India series\n',
#  'Smith debuts on Australian young rich list despite cricket ban\n',
#  'WI coach banned from 1st 2 India ODIs over inappropriate comments\n',
#  'Chelsea to send racist fans on Nazi camp trips instead of ban\n',
#  'Cricketer given 20-week ban for physical altercation in match\n',
#  "Pak's Shehzad banned for 4 months for anti-doping violation\n",
#  'Ronaldo gets 1-match ban, clear to face former club Man Utd\n',
#  "Racer who pulled rival's brake at 225kmph banned until end of 2018\n",
#  'Chair umpire who encouraged player during US Open match banned\n',
#  'Gautam Gambhir questions selective ban on India-Pakistan cricket\n',
#  'World Cup-winning captain banned from driving for 20 months\n',
#  "Motorcycle racer grabs opponent's brake at 225kmph, gets banned\n",
#  "I'm sorry, please don't ban me: Kohli recalls 'middle finger' row\n",
#  'Italian footballer banned for insulting Virgin Mary and God\n',
#  'Palestine football head banned after call to burn Messi shirts\n',
#  'Club cricketer banned for 17 matches for headbutting umpire\n',
#  'Pak batsman Jamshed banned for 10 years over spot-fixing\n',
#  'Bowler who threw ball to boundary to deny batsman ton banned\n',
#  'Ukraine athlete banned for 6 months for criticising team kit\n',
#  'Afghan player handed ban for criticising on-field umpires\n',
#  'BCCI names banned player in India Red team for Duleep Trophy\n',
#  'Winner of 12 Olympic medals banned for anti-doping violation\n',
#  'SL captain, coach and manager banned for 2 tests, 4 ODIs\n',
#  'My kids cried when Warner was banned from IPL: VVS Laxman\n',
#  'ICC to give strict ball tampering bans post Aus, SL scandals\n',
#  'SL captain Chandimal banned for a Test over ball-tampering\n',
#  'Maradona smokes cigar despite smoking ban at FIFA World Cup\n',
#  'Nigeria fans banned from carrying live chickens to WC games\n',
#  '4.6 lakh people sign petition to ban Ramos for Salah injury\n',
#  "Rugby player banned for kung fu-style kick to rival's face\n",
#  'Barca loanee handed record 16-match ban for pushing linesman\n',
#  'Ex-junior world champ shuttler banned for 20 yrs over fixing\n',
#  'Iranian women use fake beards to defy stadium ban\n',
#  'Fan banned from stadium hires crane to watch his team play\n',
#  "Warner follows Smith, Bancroft; won't challenge one-year ban\n",
#  'Steve Smith to not appeal his 12-month ban from cricket\n',
#  "Smith, Warner's ban too severe: Aus Cricketers' Association\n",
#  'Cricket Australia could ban sledging post ball-tampering row\n',
#  'Why is everyone crying: Ex-SL player mocks banned Aussies\n',
#  'Give them some space: Sachin supports banned Aus cricketers\n',
#  'This should not define them: Rohit on Smith, Warner ban\n',
#  'David Warner, Steve Smith banned from playing in IPL 2018\n',
#  'Smith, Warner banned from playing for Australia for 1 year\n',
#  '1 year ban too harsh on Smith, tweets ex-Eng captain Vaughan\n',
#  'Right decision has been taken: Sachin on Smith, Warner ban\n',
#  "Punishment doesn't fit the crime: Warne on Smith, Warner ban\n",
#  'Zimbabwe cricket official given 20-yr ban for fixing attempt\n',
#  'Watch the incident for which Steve Smith received 1-Test ban\n',
#  'Smith banned for a Test, fined 100% match fee over tampering\n',
#  'Steve Smith, David Warner could face life bans: Report\n',
#  "Rabada's ban overturned, can play in 3rd Test vs Australia\n",
#  'Happy not to be playing Tests: Kevin Pietersen on Rabada ban\n',
#  'Rabada reclaims top Test rank a day after getting 2-Test ban\n',
#  'Players hid banned Russia flag in jackets at Winter Olympics\n',
#  'Para-swimmer banned for 3 years for filming female swimmers\n',
#  "Player banned for 'not trying' mocks tennis body on Twitter\n",
#  'Footballer given 6-month doping ban for drip put 2 years ago\n',
#  'Russians defy ban, sing own anthem while Olympic song played\n',
#  'Marching under Russian flag banned at Olympics closing\n',
#  'Hurdler 1st Indian to be banned by NADA for drug possession\n',
#  'Pacer banned for match fixing working as DJ in SA pubs\n',
#  'Athlete dedicates Olympic medal to teammates on doping bans\n',
#  "SC agrees to test validity of BCCI's life ban on Sreesanth\n",
#  'French referee who kicked footballer banned for 3 months\n',
#  "Former F1 boss terms ban on 'grid girls' as 'prudish'\n",
#  'Hyderabad captain gets 2-game ban for argument over boundary\n',
#  'Life bans on 28 Russians accused of doping lifted\n',
#  "Which int'l cricketers have been banned for drug use?\n",
#  'Was taking medicine for throat infection: Yusuf on dope ban\n',
#  'Wenger given 3-match ban for misconduct against referees\n',
#  'New Sri Lanka cricket coach bans music during training\n',
#  'IOC hands 11 Russian athletes lifetime ban for doping\n',
#  'Spain could face World Cup ban over government interference\n',
#  'Lalit Modi slams BCCI over conditional revocation of RCA ban\n']

# %%
SPACY_DEP_ROOT = "ROOT"
SPACY_DEP_NSUBJ = "nsubj"
SPACY_DEP_NSUBJ_PASS = "nsubjpass"
SPACY_DEP_DOBJ = "dobj"
SPACY_DEP_PREP = "prep"
SPACY_DEP_PREP_OBJ = "pobj"
SPACY_DEP_CCOMP = "ccomp"
SPACY_DEP_IND_OBJ_1 = "dative"
SPACY_DEP_IND_OBJ_2 = "iobj"

SPACY_TAG_PREP = "IN"
SPACY_TAG_NN = "NN"
SPACY_TAG_NNS = "NNS"
SPACY_TAG_NNP = "NNP"
SPACY_TAG_NNPS = "NNPS"
SPACY_TAG_JJ = "JJ"
SPACY_TAG_JJR = "JJR"
SPACY_TAG_JJS = "JJS"
SPACY_TAG_VB = "VB"
SPACY_TAG_VBD = "VBD"
SPACY_TAG_VBG = "VBG"
SPACY_TAG_VBN = "VBN"
SPACY_TAG_VBP = "VBP"
SPACY_TAG_VBZ = "VBZ"

PREP_FOR = "for"
PREP_TO = "to"
PREP_FROM = "from"
PREP_OVER = "over"
PREP_UNTIL = "until"

def getSubTreeString(token):
    return ' '.join([str(token1.text) for token1 in list(token.subtree)])

def getHeadOfSentence(sentence):

    doc = nlp(str(sentence))
    head = None
    for token in doc:
        if token.dep_ == SPACY_DEP_ROOT:
            #print ("head",sentence, token.text)
            head = token
            
    return head  

def printTree(sentence):
    doc = nlp(str(sentence))
 
    for token in doc:
        print("{5}: {0}/{1} <--{2}-- {3}/{4} > {6};  type {7}".format(
           token.text, token.tag_, token.dep_, token.head.text, token.head.tag_,token.i,token.head.i, token.ent_id_))
        
        print(list(token.subtree))
        print ('**********')

# %%
sentence = "ICC to give sachin 3-month ban over tampering"
printTree(sentence)
parseVerbForm(sentence)
# sentence = "Para-swimmer banned for 3 years for filming female swimmers"
# printTree(sentence)
# sentence = "Smith, Warner banned from playing for Australia for 1 year"
# printTree(sentence)
# sentence = "Cricketer given 20-week ban for physical altercation in match"
# printTree(sentence)
# Out:
# 0: ICC/NNP <--nsubj-- give/VB > 2;  type
# [ICC]
# **********
# 1: to/TO <--aux-- give/VB > 2;  type
# [to]
# **********
# 2: give/VB <--ROOT-- give/VB > 2;  type
# [ICC, to, give, sachin, 3-month, ban, over, tampering]
# **********
# 3: sachin/NNP <--compound-- ban/NN > 5;  type
# [sachin]
# **********
# 4: 3-month/JJ <--amod-- ban/NN > 5;  type
# [3-month]
# **********
# 5: ban/NN <--dobj-- give/VB > 2;  type
# [sachin, 3-month, ban]
# **********
# 6: over/IN <--prep-- give/VB > 2;  type
# [over, tampering]
# **********
# 7: tampering/VBG <--pcomp-- over/IN > 6;  type
# [tampering]
# **********
# ICC to give sachin 3-month ban over tampering
#  who:  ICC  reason : tampering  timePeriod : None fromWhat: None

# %%
    
def isTypeBan(sentence):
    pass

def parse(sentence):
    pass

def parseVerbForm(sentence):
    timePeriod = None
    reason = None
    who = None
    fromWhat = None
    headToken = getHeadOfSentence(sentence)
    doc = nlp(str(sentence))

    associatedPrepositionIds = {}
    
    #Find associated Prep Ids and subject
    for token in doc:
        if token.head.i == headToken.i and token.tag_ == SPACY_TAG_PREP:
            associatedPrepositionIds[token.i] = token
        elif token.head.i == headToken.i and (token.dep_ in [SPACY_DEP_NSUBJ_PASS, SPACY_DEP_NSUBJ]):
            who = getSubTreeString(token)
            
    for token in doc:
        if token.head.i in associatedPrepositionIds:
            prep = associatedPrepositionIds[token.head.i]
            if prep.text == PREP_FOR :
                if token.tag_ in [SPACY_TAG_NN, SPACY_TAG_NNS, SPACY_TAG_NNP, SPACY_TAG_NNPS]:     
                    timePeriod = getSubTreeString(token)
                else:
                    reason = getSubTreeString(token)
            elif prep.text == PREP_FROM:
                fromWhat = getSubTreeString(token)
            elif prep.text == PREP_OVER:
                reason = getSubTreeString(token)
            elif prep.text == PREP_UNTIL:
                timePeriod = getSubTreeString(token)
                
    print(sentence)
    print(" who: ", who,
         " reason :", reason,
         " timePeriod :", timePeriod,"fromWhat:", fromWhat,'\n')
    
def parseNounForm(sentence):
    timePeriod = None
    reason = None
    who = None
    fromWhat = None
    associatedPrepositionIds = {}
    doc = nlp(str(sentence))
    headToken = getHeadOfSentence(sentence)
    
    
    for token in doc:       
        tokenLemma = wordnet_lemmatizer.lemmatize(token.text)
        if tokenLemma == 'ban' or tokenLemma == 'banned':
            banToken = token
        elif token.head.tag_ in [SPACY_TAG_VBN] and token.head.i == headToken.i and (token.dep_ in [SPACY_DEP_NSUBJ_PASS, SPACY_DEP_NSUBJ]):
            who = getSubTreeString(token)
        elif token.head.tag_ != SPACY_TAG_VBN and token.head.i == headToken.i and (token.dep_ in [SPACY_DEP_IND_OBJ_1, SPACY_DEP_IND_OBJ_2]):
            who = getSubTreeString(token)
    # Fetching preps connected to Ban tag
    for token in doc:
        if token.head.i == banToken.i and token.tag_ == SPACY_TAG_PREP:
            associatedPrepositionIds[token.i] = token
        
    for token in doc:
        if token.head.i in associatedPrepositionIds:
            prep = associatedPrepositionIds[token.head.i]
            if prep.text == PREP_FOR :
                if token.tag_ in [SPACY_TAG_NN, SPACY_TAG_NNS, SPACY_TAG_NNP, SPACY_TAG_NNPS]:     
                    timePeriod = getSubTreeString(token)
                else:
                    reason = getSubTreeString(token)
            elif prep.text == PREP_FROM:
                fromWhat = getSubTreeString(token)
            elif prep.text == PREP_OVER:
                reason = getSubTreeString(token)
            elif prep.text == PREP_UNTIL:
                timePeriod = getSubTreeString(token)
            elif prep.text == PREP_TO:
                who = getSubTreeString(token)
        elif token.head.i == banToken.i and token.tag_ in [SPACY_TAG_NN, SPACY_TAG_NNS, SPACY_TAG_NNP, SPACY_TAG_NNPS, SPACY_TAG_JJ,SPACY_TAG_JJR, SPACY_TAG_JJS]:
            timePeriod = getSubTreeString(token)
    
    print(sentence)
    print(" who: ", who,
         " reason :", reason,
         " timePeriod :", timePeriod,"fromWhat:", fromWhat,'\n')

# %%
#sentence = "Footballer given 3 matches ban for tampering"
# printTree(sentence)
# print("#################################")
#sentence = "Italian footballer banned from World cup for insulting Virgin Mary and God"
sentence = "Marching under Russian flag banned at Olympics closing"
printTree(sentence)
parseVerbForm(sentence)
#doc = nlp(sentence)
#print(list(doc.ents))
# Out:
# 0: Marching/VBG <--ROOT-- Marching/VBG > 0;  type
# [Marching, under, Russian, flag, banned, at, Olympics, closing]
# **********
# 1: under/IN <--prep-- Marching/VBG > 0;  type
# [under, Russian, flag, banned, at, Olympics, closing]
# **********
# 2: Russian/JJ <--amod-- flag/NN > 3;  type
# [Russian]
# **********
# 3: flag/NN <--pobj-- under/IN > 1;  type
# [Russian, flag, banned, at, Olympics, closing]
# **********
# 4: banned/VBN <--acl-- flag/NN > 3;  type
# [banned, at, Olympics, closing]
# **********
# 5: at/IN <--prep-- banned/VBN > 4;  type
# [at, Olympics, closing]
# **********
# 6: Olympics/NNPS <--compound-- closing/NN > 7;  type
# [Olympics]
# **********
# 7: closing/NN <--pobj-- at/IN > 5;  type
# [Olympics, closing]
# **********
# Marching under Russian flag banned at Olympics closing
#  who:  None  reason : None  timePeriod : None fromWhat: None

# %%
for sentence in sentences:
    if getHeadOfSentence(sentence).text != "banned":
        #print (sentence)
        parseNounForm(sentence)
    else:
        parseVerbForm(sentence)
# Out:
# Referee banned for using 'rock, paper, scissors' to decide kickoff
#
#  who:  Referee  reason : using ' rock , paper , scissors ' to decide kickoff
#   timePeriod : None fromWhat: None
#
# Smith, Warner bans will stand: CA chief ahead of India series
#
#  who:  None  reason : None  timePeriod : Warner fromWhat: None
#
# Smith debuts on Australian young rich list despite cricket ban
#
#  who:  None  reason : None  timePeriod : cricket fromWhat: None
#
# WI coach banned from 1st 2 India ODIs over inappropriate comments
#
#  who:  WI coach  reason : inappropriate comments
#   timePeriod : None fromWhat: 1st 2
#
# Chelsea to send racist fans on Nazi camp trips instead of ban
#
#  who:  None  reason : None  timePeriod : None fromWhat: None
#
# Cricketer given 20-week ban for physical altercation in match
#
#  who:  Cricketer  reason : None  timePeriod : physical altercation in match
#  fromWhat: None
#
# Pak's Shehzad banned for 4 months for anti-doping violation
#
#  who:  Pak 's Shehzad  reason : None  timePeriod : anti - doping violation
#  fromWhat: None
#
# Ronaldo gets 1-match ban, clear to face former club Man Utd
#
#  who:  None  reason : None  timePeriod : 1-match fromWhat: None
#
# Racer who pulled rival's brake at 225kmph banned until end of 2018
#
#  who:  None  reason : None  timePeriod : end of 2018
#  fromWhat: None
#
# Chair umpire who encouraged player during US Open match banned
#
#  who:  None  reason : None  timePeriod : None fromWhat: None
#
# Gautam Gambhir questions selective ban on India-Pakistan cricket
#
#  who:  None  reason : None  timePeriod : selective fromWhat: None
#
# World Cup-winning captain banned from driving for 20 months
#
#  who:  World Cup - winning captain  reason : None  timePeriod : None fromWhat: driving for 20 months
#
#
# Motorcycle racer grabs opponent's brake at 225kmph, gets banned
#
#  who:  None  reason : None  timePeriod : None fromWhat: None
#
# I'm sorry, please don't ban me: Kohli recalls 'middle finger' row
#
#  who:  None  reason : None  timePeriod : None fromWhat: None
#
# Italian footballer banned for insulting Virgin Mary and God
#
#  who:  Italian footballer  reason : insulting Virgin Mary and God
#   timePeriod : None fromWhat: None
#
# Palestine football head banned after call to burn Messi shirts
#
#  who:  Palestine football head  reason : None  timePeriod : None fromWhat: None
#
# Club cricketer banned for 17 matches for headbutting umpire
#
#  who:  Club cricketer  reason : None  timePeriod : 17 matches for headbutting umpire
#  fromWhat: None
#
# Pak batsman Jamshed banned for 10 years over spot-fixing
#
#  who:  Pak batsman Jamshed  reason : None  timePeriod : 10 years over fromWhat: None
#
# Bowler who threw ball to boundary to deny batsman ton banned
#
#  who:  Bowler who threw ball to boundary to deny batsman ton  reason : None  timePeriod : None fromWhat: None
#
# Ukraine athlete banned for 6 months for criticising team kit
#
#  who:  Ukraine athlete  reason : criticising team kit
#   timePeriod : 6 months fromWhat: None
#
# Afghan player handed ban for criticising on-field umpires
#
#  who:  Afghan player  reason : None  timePeriod : None fromWhat: None
#
# BCCI names banned player in India Red team for Duleep Trophy
#
#  who:  BCCI names  reason : None  timePeriod : None fromWhat: None
#
# Winner of 12 Olympic medals banned for anti-doping violation
#
#  who:  None  reason : None  timePeriod : anti - doping violation
#  fromWhat: None
#
# SL captain, coach and manager banned for 2 tests, 4 ODIs
#
#  who:  SL captain , coach and manager  reason : None  timePeriod : 2 tests fromWhat: None
#
# My kids cried when Warner was banned from IPL: VVS Laxman
#
#  who:  None  reason : None  timePeriod : Warner fromWhat: IPL
#
# ICC to give strict ball tampering bans post Aus, SL scandals
#
#  who:  None  reason : None  timePeriod : None fromWhat: None
#
# SL captain Chandimal banned for a Test over ball-tampering
#
#  who:  SL captain Chandimal  reason : None  timePeriod : a Test over ball - tampering
#  fromWhat: None
#
# Maradona smokes cigar despite smoking ban at FIFA World Cup
#
#  who:  None  reason : None  timePeriod : smoking fromWhat: None
#
# Nigeria fans banned from carrying live chickens to WC games
#
#  who:  Nigeria fans  reason : None  timePeriod : None fromWhat: carrying live chickens to WC games
#
#
# 4.6 lakh people sign petition to ban Ramos for Salah injury
#
#  who:  None  reason : None  timePeriod : Salah injury
#  fromWhat: None
#
# Rugby player banned for kung fu-style kick to rival's face
#
#  who:  Rugby player  reason : None  timePeriod : kung fu - style kick to rival 's face
#  fromWhat: None
#
# Barca loanee handed record 16-match ban for pushing linesman
#
#  who:  Barca loanee  reason : None  timePeriod : 16-match fromWhat: None
#
# Ex-junior world champ shuttler banned for 20 yrs over fixing
#
#  who:  Ex - junior world champ shuttler  reason : fixing
#   timePeriod : 20 yrs fromWhat: None
#
# Iranian women use fake beards to defy stadium ban
#
#  who:  None  reason : None  timePeriod : stadium fromWhat: None
#
# Fan banned from stadium hires crane to watch his team play
#
#  who:  None  reason : None  timePeriod : None fromWhat: stadium hires crane
#
# Warner follows Smith, Bancroft; won't challenge one-year ban
#
#  who:  None  reason : None  timePeriod : one - year fromWhat: None
#
# Steve Smith to not appeal his 12-month ban from cricket
#
#  who:  None  reason : None  timePeriod : 12-month fromWhat: cricket
#
#
# Smith, Warner's ban too severe: Aus Cricketers' Association
#
#  who:  None  reason : None  timePeriod : Warner 's fromWhat: None
#
# Cricket Australia could ban sledging post ball-tampering row
#
#  who:  None  reason : None  timePeriod : ball - tampering row
#  fromWhat: None
#
# Why is everyone crying: Ex-SL player mocks banned Aussies
#
#  who:  None  reason : None  timePeriod : None fromWhat: None
#
# Give them some space: Sachin supports banned Aus cricketers
#
#  who:  None  reason : None  timePeriod : None fromWhat: None
#
# This should not define them: Rohit on Smith, Warner ban
#
#  who:  None  reason : None  timePeriod : This should not define them : Rohit on Smith , Warner ban
#  fromWhat: None
#
# David Warner, Steve Smith banned from playing in IPL 2018
#
#  who:  David Warner , Steve Smith  reason : None  timePeriod : None fromWhat: playing in IPL 2018
#
#
# Smith, Warner banned from playing for Australia for 1 year
#
#  who:  Warner  reason : None  timePeriod : None fromWhat: playing for Australia for 1 year
#
#
# 1 year ban too harsh on Smith, tweets ex-Eng captain Vaughan
#
#  who:  None  reason : None  timePeriod : too harsh on Smith , tweets ex - Eng captain fromWhat: None
#
# Right decision has been taken: Sachin on Smith, Warner ban
#
#  who:  None  reason : None  timePeriod : Sachin on Smith , Warner ban
#  fromWhat: None
#
# Punishment doesn't fit the crime: Warne on Smith, Warner ban
#
#  who:  None  reason : None  timePeriod : Warne on Smith , Warner ban
#  fromWhat: None
#
# Zimbabwe cricket official given 20-yr ban for fixing attempt
#
#  who:  Zimbabwe cricket official  reason : fixing attempt
#   timePeriod : 20-yr fromWhat: None
#
# Watch the incident for which Steve Smith received 1-Test ban
#
#  who:  None  reason : None  timePeriod : 1-Test fromWhat: None
#
# Smith banned for a Test, fined 100% match fee over tampering
#
#  who:  Smith  reason : None  timePeriod : a Test fromWhat: None
#
# Steve Smith, David Warner could face life bans: Report
#
#  who:  None  reason : None  timePeriod : life fromWhat: None
#
# Rabada's ban overturned, can play in 3rd Test vs Australia
#
#  who:  None  reason : None  timePeriod : Rabada 's fromWhat: None
#
# Happy not to be playing Tests: Kevin Pietersen on Rabada ban
#
#  who:  None  reason : None  timePeriod : : Kevin Pietersen on Rabada ban
#  fromWhat: None
#
# Rabada reclaims top Test rank a day after getting 2-Test ban
#
#  who:  None  reason : None  timePeriod : 2-Test fromWhat: None
#
# Players hid banned Russia flag in jackets at Winter Olympics
#
#  who:  Players  reason : None  timePeriod : None fromWhat: None
#
# Para-swimmer banned for 3 years for filming female swimmers
#
#  who:  Para - swimmer  reason : None  timePeriod : 3 years for filming female swimmers
#  fromWhat: None
#
# Player banned for 'not trying' mocks tennis body on Twitter
#
#  who:  Player  reason : ' not trying ' mocks tennis body on Twitter
#   timePeriod : None fromWhat: None
#
# Footballer given 6-month doping ban for drip put 2 years ago
#
#  who:  Footballer  reason : None  timePeriod : drip fromWhat: None
#
# Russians defy ban, sing own anthem while Olympic song played
#
#  who:  None  reason : None  timePeriod : None fromWhat: None
#
# Marching under Russian flag banned at Olympics closing
#
#  who:  None  reason : None  timePeriod : None fromWhat: None
#
# Hurdler 1st Indian to be banned by NADA for drug possession
#
#  who:  Indian  reason : None  timePeriod : drug possession
#  fromWhat: None
#
# Pacer banned for match fixing working as DJ in SA pubs
#
#  who:  Pacer  reason : match fixing working as DJ in SA pubs
#   timePeriod : None fromWhat: None
#
# Athlete dedicates Olympic medal to teammates on doping bans
#
#  who:  to teammates on doping bans
#   reason : None  timePeriod : None fromWhat: None
#
# SC agrees to test validity of BCCI's life ban on Sreesanth
#
#  who:  None  reason : None  timePeriod : life fromWhat: None
#
# French referee who kicked footballer banned for 3 months
#
#  who:  French referee who kicked footballer  reason : None  timePeriod : 3 months
#  fromWhat: None
#
# Former F1 boss terms ban on 'grid girls' as 'prudish'
#
#  who:  None  reason : None  timePeriod : Former F1 boss terms fromWhat: None
#
# Hyderabad captain gets 2-game ban for argument over boundary
#
#  who:  None  reason : None  timePeriod : argument over boundary
#  fromWhat: None
#
# Life bans on 28 Russians accused of doping lifted
#
#  who:  None  reason : None  timePeriod : Life fromWhat: None
#
# Which int'l cricketers have been banned for drug use?
#
#  who:  None  reason : None  timePeriod : drug use fromWhat: None
#
# Was taking medicine for throat infection: Yusuf on dope ban
#
#  who:  None  reason : None  timePeriod : dope fromWhat: None
#
# Wenger given 3-match ban for misconduct against referees
#
#  who:  Wenger  reason : None  timePeriod : misconduct against referees
#  fromWhat: None
#
# New Sri Lanka cricket coach bans music during training
#
#  who:  None  reason : None  timePeriod : music fromWhat: None
#
# IOC hands 11 Russian athletes lifetime ban for doping
#
#  who:  None  reason : None  timePeriod : doping
#  fromWhat: None
#
# Spain could face World Cup ban over government interference
#
#  who:  None  reason : None  timePeriod : World Cup fromWhat: None
#
# Lalit Modi slams BCCI over conditional revocation of RCA ban
#
#  who:  None  reason : None  timePeriod : RCA fromWhat: None

# %%
# for sentence in sentences:
#     sentence = sentence.replace('\n','')
#     parse(sentence)

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer() 
wordnet_lemmatizer.lemmatize("banned")
# Out:
# 'banned'

# %%
#Working Sentences
# ICC gives 3 matches ban to Footballer for tampering
# Afghan player given ban for criticising on-field umpires
# Pak's Shehzad banned for 4 months for ball tampering
# Italian footballer banned from World cup for insulting Virgin Mary and God
