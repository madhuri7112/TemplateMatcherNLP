# %%
import spacy

# %%
with open('share') as data_file:
        sentences = data_file.readlines()

# %%
sentences
# Out:
# ['After surviving accident, Manjrekar shares pic of shattered door\n',
#  'Shuttler Ajay Jayaram decorates rangoli on Diwali, shares picture\n',
#  "Dhoni shares 'PUBG fan' Kohli's old pic with toy gun on birthday\n",
#  'Pitch invader shares selfie clicked by Cristiano Ronaldo for him\n',
#  'Anything is possible: Kohli shares pic of physical transformation\n',
#  "Krunal shares 'legendary' pictures of brother Hardik on birthday\n",
#  'Jwala shares #MeToo story of mental harassment by badminton chief\n',
#  "Juventus' shares fall 5% after rape allegations against Ronaldo\n",
#  'Rohit, Dhawan share 210-run stand vs Pak, break 20-year-old record\n',
#  'Two teams share top spot for the first time in FIFA rankings\n',
#  "Zlatan shares 'God of Goals' poster made in honour of 500th goal\n",
#  'Messi shares photos of him dropping his kids to school\n',
#  'Murray shares image of bloodied nose after daughter hits him\n',
#  'Dhawan shares video of improvised slip catching drill\n',
#  "Novak shares 'naked' ice bath with opponent in US Open break\n",
#  'Bhaag dhanno bhaag: Dhawan shares pic with debutant Pant\n',
#  "BCCI shares video of Pandya posing next to Honour's Board\n",
#  'Sania Mirza shares photo with her 8 Asian Games medals\n',
#  'John Cena shares photos of Kapil Sharma, Daler on Instagram\n',
#  'Dhoni enjoys waterfall near Ranchi after 10yrs, shares video\n',
#  "BCCI shares lunch menu of Lord's Test as Day's start delayed\n",
#  "Anand Mahindra shares video of Praneeth's 'impossible' shot\n",
#  'Ex-Aus pacer McGrath shares knowledge with Haryana cricketers\n',
#  'BCCI shares pictures of Saha following surgery in England\n',
#  'Brutal: ECB shares video of Cook, Anderson taking Yo-Yo test\n',
#  "ICC shares video of 2-yr-old kid playing 'gorgeous' shots\n",
#  'Kohli shares pic with Anushka, gets trolled over his haircut\n',
#  "Italian club's share rises 20% over Ronaldo's transfer rumour\n",
#  'Mohammad Shami sees daughter after 3 months, shares picture\n',
#  'Rashid shares video of place where he began playing cricket\n',
#  "Shane Warne shares pic with Ed Sheeran having beer at Lord's\n",
#  'Tughlaqi Farmaan: Dutt on Haryana govt seeking pay share\n',
#  'Working out like a boss: Kohli shares gym video with Anushka\n',
#  "Raina shares Chhetri's video, urges fans to support them\n",
#  "Pak journo shares pic of Irrfan watching match at Lord's\n",
#  "Sachin shares throwback picture on Ravi Shastri's birthday\n",
#  'Madhuri shares photo with Gavaskar on her birthday\n',
#  'ICC shares old video of Asaram, PM Modi after rape verdict\n',
#  'Will share champagne with Virat if he hits 50 tons: Sachin\n',
#  "IPL shares video of Dhoni-Yuvraj 'bromance' in CSK-KXIP game\n",
#  'Dhoni shares video of daughter wanting to hug him in match\n',
#  'Cyclist shares image of himself after a 257-km race\n',
#  "Juventus' shares fall to 8-month low after Ronaldo's goal\n",
#  'Dhawan shares video of him playing beach cricket with family\n',
#  "Pietersen shares Aussies' 'We cheat at cricket' parody video\n",
#  'Bopanna shares pic of Bhatura stall named after Federer\n',
#  'Shami shares bank statement, reveals he paid wife 1 lakh\n',
#  "Want to meet CM Mamata and share my pain: Shami's wife\n",
#  'Uthappa shares pic of physical transformation ahead of IPL\n',
#  "DD share picture of Gambhir as Batman, call it 'Gautam City'\n",
#  'Ik chumma tu muj ko udhar de: Harbhajan shares pic with Kaif\n',
#  'Ronaldo shares picture of son imitating shirtless pose\n',
#  'Pietersen shares video with adopted baby leopard in India\n',
#  'My one and only: Kohli shares pic with wife Anushka Sharma\n',
#  'Pak cricketer Shahzad shares workout pic with Wasim Akram\n',
#  "Chahal shares 'bromance' pic with Kuldeep on Valentine's Day\n",
#  'Kings XI Punjab share pic of Chris Gayle donning turban\n',
#  'Player shares pic of injury after retiring against Federer\n',
#  'Jadeja shares selfie with lion after being fined earlier\n',
#  "Sachin shares throwback pictures on Vinod Kambli's birthday\n",
#  'Enrique, Anna Kournikova share first pics of newborn twins\n',
#  'Sachin Tendulkar shares video of him picking lemon from tree\n',
#  'Jonty Rhodes shares pic of family bathing in Ganga river\n',
#  "Team India shares pic of Steyn checking out Umesh's tattoo\n",
#  'Ronaldo shares photo with 15 of his individual trophies\n',
#  "Yuvraj shares pre-New Year's party pic with Sachin, Agarkar\n",
#  "Sachin shares video of Kaif's son batting vs him via machine\n",
#  "Virat Kohli asks Rohit Sharma to share 'double ton handbook'\n",
#  'Anushka shares pic with husband Virat from their honeymoon\n',
#  'John Cena shares inspirational quote by Rahul Dravid\n']

# %%
SPACY_DEP_ROOT = "ROOT"
SPACY_DEP_NSUBJ = "nsubj"
SPACY_DEP_DOBJ = "dobj"
SPACY_DEP_PREP = "prep"
SPACY_DEP_PREP_OBJ = "pobj"
SPACY_DEP_CCOMP = "ccomp"
SPACY_TAG_PREP = "IN"

# %%
nlp = spacy.load('en_core_web_lg')

# %%
def printTree(sentence):
    doc = nlp(str(sentence))
 
    for token in doc:
        print("{5}: {0}/{1} <--{2}-- {3}/{4} > {6}".format(
           token.text, token.tag_, token.dep_, token.head.text, token.head.tag_,token.i,token.head.i))
        
        print(list(token.subtree))
        print ('**********')

sentence = str("John shows a post about his daughter")
sentence = sentence.replace('shares', 'shows')
sentence = sentence.replace('share', 'show')
printTree(sentence)
parse(sentence)
#print(getCompoundPhrase("Uthappa shows pic of physical transformation ahead of IPL", 5))
#printTree(u"After surviving accident, Manjrekar shows pic of shattered door")
#parse(u"After surviving accident, Manjrekar shows pic of shattered door")
#Yuvraj shows pre-New Year's party pic with Sachin, Agarkar
# Out:
# 0: John/NNP <--nsubj-- shows/VBZ > 1
# [John]
# **********
# 1: shows/VBZ <--ROOT-- shows/VBZ > 1
# [John, shows, a, post, about, his, daughter]
# **********
# 2: a/DT <--det-- post/NN > 3
# [a]
# **********
# 3: post/NN <--dobj-- shows/VBZ > 1
# [a, post, about, his, daughter]
# **********
# 4: about/IN <--prep-- post/NN > 3
# [about, his, daughter]
# **********
# 5: his/PRP$ <--poss-- daughter/NN > 6
# [his]
# **********
# 6: daughter/NN <--pobj-- about/IN > 4
# [his, daughter]
# **********
# John shows a post about his daughter
# who:  John type:  a post what:  about his daughter

# %%
def getCompoundPhrase(sentence, rootTokenId):
    doc = nlp(str(sentence))
    phrase = []
    for token in doc:
        if (token.tag_ != SPACY_TAG_PREP) and (token.head.i == rootTokenId or token.i == rootTokenId):
            phrase.append(token.text)
    reversed(phrase)
    return ' '.join(phrase)

# %%
def getHeadOfSentence(sentence):

    doc = nlp(str(sentence))
    head = None
    for token in doc:
        if token.dep_ == SPACY_DEP_ROOT:
            #print ("head",sentence, token.text)
            head = token
            
    return head

# %%
def parse(sentence):
    doc = nlp(str(sentence))
    whoShared = None
    whoSharedId = None
    
    typeShared = None
    typeSharedId = None
    
    whatShared = None
    whatSharedId = None
    
    prep = None
    prepId = None
    ww = ''
    sentenceHeadToken = getHeadOfSentence(sentence)
    sentenceHead = sentenceHeadToken.text
    #print("sent head: ", sentenceHead)
    for token in doc:
        # if token.dep_ == SPACY_DEP_ROOT:
        #     print (sentence, token.text)
        if token.dep_ == SPACY_DEP_NSUBJ and token.head.text == sentenceHead:
            whoShared = token.text
            whoSharedId = token.i
        if (token.dep_ == SPACY_DEP_DOBJ or token.dep_ == SPACY_DEP_CCOMP) and token.head.text == sentenceHead :
            typeShared = token.text
            typeSharedId = token.i
            
    #Figuring out preposition for typeShared       
    for token in doc:
        if token.dep_ == SPACY_DEP_PREP and token.head.text == typeShared:
            prep = token.text
            prepId = token.i
            
            #for token1 in 
            ww = [str(token1.text) for token1 in list(token.subtree)]
            break
    if prep != None:
        for token in doc:
            if token.dep_ == SPACY_DEP_PREP_OBJ and token.head.i == prepId:
                whatShared = token.text
                whatSharedId = token.i
    #print(sentence, "who: ", whoShared, "type: ", typeShared, "what: ", whatShared)
    print(sentence)
    print("who: ", getCompoundPhrase(sentence, whoSharedId), 
          "type: ", getCompoundPhrase(sentence, typeSharedId), 
          #"what: ", getCompoundPhrase(sentence, whatSharedId))
          "what: ", ' '.join(ww))
    print('\n')

# with -> subj with someone ; attached to noun(video, pic)
# in, at -> place ; attached to subj
# of -> content ; attached to noun(video, pic)
# on -> timeframe

# %%
for sentence in sentences:
    sentence = sentence.replace('shares', 'shows')
    sentence = sentence.replace('share', 'show')
    sentence = sentence.replace('\n','')
    #getHeadOfSentence(sentence)
    parse(sentence)
# Out:
# After surviving accident, Manjrekar shows pic of shattered door
# who:  Manjrekar type:  pic what:  of shattered door
#
#
# Shuttler Ajay Jayaram decorates rangoli on Diwali, shows picture
# who:  Shuttler Ajay Jayaram type:  rangoli what:
#
#
# Dhoni shows 'PUBG fan' Kohli's old pic with toy gun on birthday
# who:  Dhoni type:  fan Kohli old pic what:  with toy gun
#
#
# Pitch invader shows selfie clicked by Cristiano Ronaldo for him
# who:  Pitch invader type:  selfie clicked what:
#
#
# Anything is possible: Kohli shows pic of physical transformation
# who:  Kohli type:  pic what:  of physical transformation
#
#
# Krunal shows 'legendary' pictures of brother Hardik on birthday
# who:   type:   what:
#
#
# Jwala shows #MeToo story of mental harassment by badminton chief
# who:  Jwala type:  # MeToo story what:  of mental harassment by badminton chief
#
#
# Juventus' shows fall 5% after rape allegations against Ronaldo
# who:  Juventus shows type:   what:
#
#
# Rohit, Dhawan show 210-run stand vs Pak, break 20-year-old record
# who:  Dhawan type:  210-run stand what:  vs Pak
#
#
# Two teams show top spot for the first time in FIFA rankings
# who:  Two teams type:  top spot what:  for the first time in FIFA rankings
#
#
# Zlatan shows 'God of Goals' poster made in honour of 500th goal
# who:  Zlatan type:  God what:  of Goals ' poster made in honour of 500th goal
#
#
# Messi shows photos of him dropping his kids to school
# who:  Messi type:  photos dropping kids what:  to school
#
#
# Murray shows image of bloodied nose after daughter hits him
# who:  Murray type:  image what:  of bloodied nose
#
#
# Dhawan shows video of improvised slip catching drill
# who:  Dhawan type:  video what:  of improvised slip catching drill
#
#
# Novak shows 'naked' ice bath with opponent in US Open break
# who:  Novak type:  naked ' ice bath what:  with opponent in US Open break
#
#
# Bhaag dhanno bhaag: Dhawan shows pic with debutant Pant
# who:   type:  Dhawan shows pic what:
#
#
# BCCI shows video of Pandya posing next to Honour's Board
# who:  BCCI type:  video posing what:  of Pandya
#
#
# Sania Mirza shows photo with her 8 Asian Games medals
# who:  Sania Mirza type:  photo what:  with her 8 Asian Games medals
#
#
# John Cena shows photos of Kapil Sharma, Daler on Instagram
# who:  John Cena type:  photos what:  of Kapil Sharma , Daler on Instagram
#
#
# Dhoni enjoys waterfall near Ranchi after 10yrs, shows video
# who:  Dhoni type:  waterfall what:  near Ranchi
#
#
# BCCI shows lunch menu of Lord's Test as Day's start delayed
# who:  BCCI type:  lunch menu what:  of Lord 's Test
#
#
# Anand Mahindra shows video of Praneeth's 'impossible' shot
# who:  Anand Mahindra type:  video what:  of Praneeth 's ' impossible ' shot
#
#
# Ex-Aus pacer McGrath shows knowledge with Haryana cricketers
# who:  pacer McGrath type:  knowledge what:  with Haryana cricketers
#
#
# BCCI shows pictures of Saha following surgery in England
# who:  BCCI type:  pictures what:  of Saha
#
#
# Brutal: ECB shows video of Cook, Anderson taking Yo-Yo test
# who:  ECB type:  Anderson taking test what:
#
#
# ICC shows video of 2-yr-old kid playing 'gorgeous' shots
# who:  ICC type:  video what:  of 2-yr - old kid playing ' gorgeous ' shots
#
#
# Kohli shows pic with Anushka, gets trolled over his haircut
# who:  Kohli type:  pic what:  with Anushka
#
#
# Italian club's show rises 20% over Ronaldo's transfer rumour
# who:  club show type:   what:
#
#
# Mohammad Shami sees daughter after 3 months, shows picture
# who:  Mohammad Shami type:  daughter what:
#
#
# Rashid shows video of place where he began playing cricket
# who:  Rashid type:  video began what:  of place
#
#
# Shane Warne shows pic with Ed Sheeran having beer at Lord's
# who:  Shane Warne type:  pic what:  with Ed Sheeran having beer at Lord 's
#
#
# Tughlaqi Farmaan: Dutt on Haryana govt seeking pay show
# who:   type:   what:
#
#
# Working out like a boss: Kohli shows gym video with Anushka
# who:  Kohli type:  gym video what:  with Anushka
#
#
# Raina shows Chhetri's video, urges fans to support them
# who:  Raina type:  Chhetri video what:
#
#
# Pak journo shows pic of Irrfan watching match at Lord's
# who:  Pak journo type:  pic what:  of Irrfan
#
#
# Sachin shows throwback picture on Ravi Shastri's birthday
# who:  Sachin type:  throwback picture what:  on Ravi Shastri 's birthday
#
#
# Madhuri shows photo with Gavaskar on her birthday
# who:  Madhuri type:  photo what:  with Gavaskar
#
#
# ICC shows old video of Asaram, PM Modi after rape verdict
# who:  ICC type:  old video what:  of Asaram , PM Modi after rape verdict
#
#
# Will show champagne with Virat if he hits 50 tons: Sachin
# who:   type:  champagne what:
#
#
# IPL shows video of Dhoni-Yuvraj 'bromance' in CSK-KXIP game
# who:  IPL type:  video what:  of Dhoni - Yuvraj ' bromance ' in CSK - KXIP game
#
#
# Dhoni shows video of daughter wanting to hug him in match
# who:  Dhoni type:  video wanting what:  of daughter
#
#
# Cyclist shows image of himself after a 257-km race
# who:  Cyclist type:  image what:  of himself
#
#
# Juventus' shows fall to 8-month low after Ronaldo's goal
# who:  Juventus shows type:   what:
#
#
# Dhawan shows video of him playing beach cricket with family
# who:  Dhawan type:  video what:  of him
#
#
# Pietersen shows Aussies' 'We cheat at cricket' parody video
# who:  Pietersen type:  ' We cheat what:  at cricket ' parody video
#
#
# Bopanna shows pic of Bhatura stall named after Federer
# who:  Bopanna type:  pic what:  of Bhatura stall named after Federer
#
#
# Shami shows bank statement, reveals he paid wife 1 lakh
# who:   type:  he paid wife lakh what:
#
#
# Want to meet CM Mamata and show my pain: Shami's wife
# who:   type:   what:
#
#
# Uthappa shows pic of physical transformation ahead of IPL
# who:  Uthappa type:  pic what:  of physical transformation
#
#
# DD show picture of Gambhir as Batman, call it 'Gautam City'
# who:  DD show picture type:  it what:
#
#
# Ik chumma tu muj ko udhar de: Harbhajan shows pic with Kaif
# who:  Harbhajan type:  pic what:  with Kaif
#
#
# Ronaldo shows picture of son imitating shirtless pose
# who:  Ronaldo type:  picture what:  of son imitating shirtless pose
#
#
# Pietersen shows video with adopted baby leopard in India
# who:  Pietersen type:  video what:  with adopted baby leopard in India
#
#
# My one and only: Kohli shows pic with wife Anushka Sharma
# who:  Kohli type:  pic what:  with wife Anushka Sharma
#
#
# Pak cricketer Shahzad shows workout pic with Wasim Akram
# who:  cricketer Shahzad type:  workout pic what:  with Wasim Akram
#
#
# Chahal shows 'bromance' pic with Kuldeep on Valentine's Day
# who:  Chahal type:  bromance pic what:  with Kuldeep on Valentine 's Day
#
#
# Kings XI Punjab show pic of Chris Gayle donning turban
# who:   type:   what:
#
#
# Player shows pic of injury after retiring against Federer
# who:  Player type:  pic what:  of injury
#
#
# Jadeja shows selfie with lion after being fined earlier
# who:  Jadeja type:  selfie what:  with lion
#
#
# Sachin shows throwback pictures on Vinod Kambli's birthday
# who:  Sachin type:  throwback pictures what:  on Vinod Kambli 's birthday
#
#
# Enrique, Anna Kournikova show first pics of newborn twins
# who:  Anna Kournikova type:  first pics what:  of newborn twins
#
#
# Sachin Tendulkar shows video of him picking lemon from tree
# who:  Sachin Tendulkar type:  video picking what:  of him
#
#
# Jonty Rhodes shows pic of family bathing in Ganga river
# who:  Jonty Rhodes type:  pic what:  of family bathing in Ganga river
#
#
# Team India shows pic of Steyn checking out Umesh's tattoo
# who:  Team India type:  pic what:  of Steyn checking out Umesh 's tattoo
#
#
# Ronaldo shows photo with 15 of his individual trophies
# who:  Ronaldo type:  photo what:  with 15 of his individual trophies
#
#
# Yuvraj shows pre-New Year's party pic with Sachin, Agarkar
# who:  Yuvraj type:  Year party pic what:  with Sachin , Agarkar
#
#
# Sachin shows video of Kaif's son batting vs him via machine
# who:  Sachin type:  video what:  of Kaif 's son batting vs him via machine
#
#
# Virat Kohli asks Rohit Sharma to show 'double ton handbook'
# who:  Virat Kohli type:  Rohit Sharma what:
#
#
# Anushka shows pic with husband Virat from their honeymoon
# who:  Anushka type:  pic what:  with husband Virat
#
#
# John Cena shows inspirational quote by Rahul Dravid
# who:  John Cena type:  inspirational quote what:  by Rahul Dravid
