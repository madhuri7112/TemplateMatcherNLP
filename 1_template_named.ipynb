# %%
import spacy
from nltk.stem import WordNetLemmatizer

# %%
with open('named') as data_file:
        sentences = data_file.readlines()

# %%
nlp = spacy.load('en_core_web_lg')
wordnet_lemmatizer = WordNetLemmatizer()

# %%
sentences
# Out:
# ["Dhoni not named in India's squads for T20Is against WI, Australia\n",
#  'Brazil legend Pele was named after American inventor Thomas Edison\n',
#  "Ex-WC winning Arsenal player Henry named Monaco's head coach\n",
#  'Shaw 6th Indian to be named Man of the Match on Test debut\n',
#  "16-yr-old Manu named India's flag-bearer at Youth Olympics\n",
#  "Modric who led Croatia to WC final named Best FIFA Men's Player\n",
#  "France's World Cup-winning manager named Best FIFA Men's Coach\n",
#  "18-yr-old swimmer who bagged 6 golds named 2018 Asiad's MVP\n",
#  'Warne to be named RR coach, KXIP and RCB sack their coaches\n',
#  'Manager who led India to WT20 2007 title named Zimbabwe coach\n',
#  "India's U-19 WC-winning captain named in squad for Eng Tests\n",
#  "Ex-India player pips Kohli's coach, named women's team coach\n",
#  'Lionel Messi named Barcelona captain for 2018-19 season\n',
#  'Did he drop trophy, tweets user as Akmal named best keeper\n',
#  'Mumbai-born spinner named in NZ squad for Tests vs Pakistan\n',
#  'Indian captain Sunil Chhetri named AIFF Player of 2017\n',
#  "Mayweather named world's highest paid celebrity with $285 million\n",
#  "England's Kane wins Golden Boot, Croatia's Modric named best player\n",
#  "Hima Das to be named Assam's sports ambassador\n",
#  "A wine is named after Iniesta's 116th minute WC final goal\n",
#  'Player named Flying Dutchman scored flying header in 2014 WC\n',
#  'Who is ex-Barcelona player named new boss of Real Madrid?\n',
#  "Mayweather named world's highest-paid athlete with $285 million\n",
#  'After Arbaaz, Sajid Khan named in IPL betting racket\n',
#  'There is an asteroid named after tennis star Rafael Nadal\n',
#  '20-yr-old who hit most 6s in IPL 2018 named Emerging Player\n',
#  'Eden Gardens named best venue and ground of IPL 2018\n',
#  'Ronaldo named most famous athlete again, Kohli ranked 11th\n',
#  "India's WT20-winning manager named Zimbabwe's interim coach\n",
#  'Kohli named in Ireland T20 tour despite county on same dates\n',
#  'Tim Paine and Aaron Finch named Aus captains in ODI and T20I\n',
#  "Messi wins case against firm named 'Massi' over name\n",
#  "Kohli named Wisden's leading cricketer for 2nd straight year\n",
#  'Smith sacked as Aus Test captain, Paine named replacement\n',
#  "Rahul Dravid named election icon for K'taka Assembly polls\n",
#  'Bopanna shares pic of Bhatura stall named after Federer\n',
#  'Journo named Steve Smith wrongly slammed for ball-tampering\n',
#  "B'desh dressing room damaged after win over SL, player named\n",
#  'Virat Kohli named first Brand Ambassador for Uber India\n',
#  "Player named Watt shown red as ref confuses name with 'What'\n",
#  '2-time IPL-winning captain Gambhir named Daredevils skipper\n',
#  'Sunil Gavaskar named as Commissioner of T20 Mumbai League\n',
#  'Dinesh Karthik named captain of Kolkata Knight Riders\n',
#  'Indian wins gold, named best boxer of tournament in Bulgaria\n',
#  'Shoaib Akhtar named brand ambassador of Pak Cricket Board\n',
#  "IPL's highest wicket-taker Malinga named MI's bowling mentor\n",
#  'Galaxy 12.9 billion light-years away is named after Ronaldo\n',
#  'Bumrah, Harmanpreet named in Forbes India 30 Under 30 list\n',
#  "Raina named in India's 16-man squad for T20I series vs SA\n",
#  'Virat Kohli named ICC Cricketer of the Year\n',
#  'Steve Smith named ICC Test Cricketer of the Year\n',
#  '3 Indians in ICC Test Team of the Year, Kohli named captain\n',
#  "Chahal's 6/25 vs England named T20I Performance of the Year\n",
#  "India's CT defeat vs Pak named ICC Fans' Moment of the Year\n",
#  'Manchester United legend Ryan Giggs named as Wales manager\n',
#  'Nadal, Federer named top seeds for Australian Open\n',
#  "Stokes named in England's T20I squad for upcoming tri-series\n",
#  'Lara named daughter after Sydney where he hit 277 as 1st ton\n',
#  "Liverpool's Mohamed Salah named African Footballer of 2017\n"]

# %%
SPACY_DEP_ROOT = "ROOT"
SPACY_DEP_NSUBJ = "nsubj"
SPACY_DEP_NSUBJ_PASS = "nsubjpass"
SPACY_DEP_DOBJ = "dobj"
SPACY_DEP_PREP = "prep"
SPACY_DEP_PREP_OBJ = "pobj"
SPACY_DEP_CCOMP = "ccomp"
SPACY_DEP_IND_OBJ_1 = "dative"
SPACY_DEP_IND_OBJ_2 = "iobj"

SPACY_TAG_PREP = "IN"
SPACY_TAG_NN = "NN"
SPACY_TAG_NNS = "NNS"
SPACY_TAG_NNP = "NNP"
SPACY_TAG_NNPS = "NNPS"
SPACY_TAG_JJ = "JJ"
SPACY_TAG_JJR = "JJR"
SPACY_TAG_JJS = "JJS"
SPACY_TAG_VB = "VB"
SPACY_TAG_VBD = "VBD"
SPACY_TAG_VBG = "VBG"
SPACY_TAG_VBN = "VBN"
SPACY_TAG_VBP = "VBP"
SPACY_TAG_VBZ = "VBZ"

SPACY_NER_MONEY = "MONEY"
SPACY_NER_CARDINAL = "CARDINAL"

PREP_FOR = "for"
PREP_TO = "to"
PREP_FROM = "from"
PREP_OVER = "over"
PREP_UNTIL = "until"
PREP_AFTER = "after"
PREP_AS = "as"

SPACY_SUBJECTS = ["nsubj", "nsubjpass", "csubj", "csubjpass", "agent", "expl"]
SPACY_OBJECTS = ["dobj", "dative", "attr", "oprd"]
SPACY_ADJECTIVES = ["acomp", "advcl", "advmod", "amod", "appos", "nn", "nmod", "ccomp", "complm",
              "hmod", "infmod", "xcomp", "rcmod", "poss"," possessive"]
SPACY_COMPOUNDS = ["compound"]
SPACY_PREPOSITIONS = ["prep"]

def getSubTreeString(token):
    return ' '.join([str(token1.text) for token1 in list(token.subtree)])

def getHeadOfSentence(sentence):

    doc = nlp(str(sentence))
    head = None
    for token in doc:
        if token.dep_ == SPACY_DEP_ROOT:
            #print ("head",sentence, token.text)
            head = token
            
    return head  

def printTree(sentence):
    doc = nlp(str(sentence))
 
    for token in doc:
        print("{5}: {0}/{1} <--{2}-- {3}/{4} > {6};  type {7}".format(
           token.text, token.tag_, token.dep_, token.head.text, token.head.tag_,token.i,token.head.i, token.ent_id_))
        
        print(list(token.subtree))
        print ('**********')

#def printNamedEntitied(sentence):
    
def printNamedEntities(sentence):
    doc = nlp(sentence)
    print ("Named entities\n")
    for ent in list(doc.ents):
        print(ent.text, ent.label_)

# %%
sentence = "Shaw 6th Indian to be named Man of the Match on Test debut"
#doc = nlp(sentence)
printNamedEntities(sentence)
printTree(sentence)
parse(sentence)
#parseVerbForm(sentence)
# Out:
# Named entities
#
# Shaw 6th Indian ORG
# Man of the Match WORK_OF_ART
# 0: Shaw/NNP <--compound-- 6th/NN > 1;  type
# [Shaw]
# **********
# 1: 6th/NN <--compound-- Indian/NNP > 2;  type
# [Shaw, 6th]
# **********
# 2: Indian/NNP <--ROOT-- Indian/NNP > 2;  type
# [Shaw, 6th, Indian, to, be, named, Man, of, the, Match, on, Test, debut]
# **********
# 3: to/TO <--aux-- named/VBN > 5;  type
# [to]
# **********
# 4: be/VB <--auxpass-- named/VBN > 5;  type
# [be]
# **********
# 5: named/VBN <--relcl-- Indian/NNP > 2;  type
# [to, be, named, Man, of, the, Match, on, Test, debut]
# **********
# 6: Man/NNP <--oprd-- named/VBN > 5;  type
# [Man, of, the, Match, on, Test, debut]
# **********
# 7: of/IN <--prep-- Man/NNP > 6;  type
# [of, the, Match, on, Test, debut]
# **********
# 8: the/DT <--det-- Match/NNP > 9;  type
# [the]
# **********
# 9: Match/NNP <--pobj-- of/IN > 7;  type
# [the, Match, on, Test, debut]
# **********
# 10: on/IN <--prep-- Match/NNP > 9;  type
# [on, Test, debut]
# **********
# 11: Test/NNP <--compound-- debut/NN > 12;  type
# [Test]
# **********
# 12: debut/NN <--pobj-- on/IN > 10;  type
# [Test, debut]
# **********
# Shaw 6th Indian to be named Man of the Match on Test debut
# Who:  None   name: Man of the Match on Test debut

# %%
def parse(sentence):
    doc = nlp(sentence)
    whoWasNamed = None
    name = None
    headToken = getHeadOfSentence(sentence)
    namedToken = None
    for token in doc:
        if token.text == "named":
            namedToken = token 
    for token in doc:
        if token.dep_ in [SPACY_DEP_NSUBJ, SPACY_DEP_NSUBJ_PASS]:
            whoWasNamed = getSubTreeString(token)
        elif token.dep_ in SPACY_OBJECTS:
            name = getSubTreeString(token)
    print(sentence)
    print ("Who: ", whoWasNamed, "  name:", name)
    print('\n')

# %%
for sentence in sentences:
    sentence = sentence.replace('\n','')
    parse(sentence)
# Out:
# Dhoni not named in India's squads for T20Is against WI, Australia
# Who:  None   name: None
#
#
# Brazil legend Pele was named after American inventor Thomas Edison
# Who:  Brazil legend Pele   name: None
#
#
# Ex-WC winning Arsenal player Henry named Monaco's head coach
# Who:  Ex - WC winning Arsenal player Henry   name: Monaco 's head coach
#
#
# Shaw 6th Indian to be named Man of the Match on Test debut
# Who:  None   name: Man of the Match on Test debut
#
#
# 16-yr-old Manu named India's flag-bearer at Youth Olympics
# Who:  16-yr - old Manu   name: India 's flag - bearer at Youth Olympics
#
#
# Modric who led Croatia to WC final named Best FIFA Men's Player
# Who:  who   name: Best FIFA Men 's Player
#
#
# France's World Cup-winning manager named Best FIFA Men's Coach
# Who:  None   name: Best FIFA Men 's Coach
#
#
# 18-yr-old swimmer who bagged 6 golds named 2018 Asiad's MVP
# Who:  who   name: 2018 Asiad 's MVP
#
#
# Warne to be named RR coach, KXIP and RCB sack their coaches
# Who:  Warne   name: their coaches
#
#
# Manager who led India to WT20 2007 title named Zimbabwe coach
# Who:  who   name: Zimbabwe coach
#
#
# India's U-19 WC-winning captain named in squad for Eng Tests
# Who:  None   name: None
#
#
# Ex-India player pips Kohli's coach, named women's team coach
# Who:  Ex - India player   name: women 's team coach
#
#
# Lionel Messi named Barcelona captain for 2018-19 season
# Who:  Lionel Messi   name: Barcelona captain
#
#
# Did he drop trophy, tweets user as Akmal named best keeper
# Who:  Akmal   name: best keeper
#
#
# Mumbai-born spinner named in NZ squad for Tests vs Pakistan
# Who:  None   name: None
#
#
# Indian captain Sunil Chhetri named AIFF Player of 2017
# Who:  Indian captain Sunil Chhetri   name: AIFF Player of 2017
#
#
# Mayweather named world's highest paid celebrity with $285 million
# Who:  Mayweather   name: world 's highest paid celebrity
#
#
# England's Kane wins Golden Boot, Croatia's Modric named best player
# Who:  England 's Kane   name: best player
#
#
# Hima Das to be named Assam's sports ambassador
# Who:  Hima Das   name: Assam 's sports ambassador
#
#
# A wine is named after Iniesta's 116th minute WC final goal
# Who:  A wine   name: None
#
#
# Player named Flying Dutchman scored flying header in 2014 WC
# Who:  Player named Flying Dutchman   name: flying header
#
#
# Who is ex-Barcelona player named new boss of Real Madrid?
# Who:  None   name: new boss of Real Madrid
#
#
# Mayweather named world's highest-paid athlete with $285 million
# Who:  Mayweather   name: world 's highest - paid athlete
#
#
# After Arbaaz, Sajid Khan named in IPL betting racket
# Who:  None   name: None
#
#
# There is an asteroid named after tennis star Rafael Nadal
# Who:  None   name: an asteroid named after tennis star Rafael Nadal
#
#
# 20-yr-old who hit most 6s in IPL 2018 named Emerging Player
# Who:  who   name: Emerging Player
#
#
# Eden Gardens named best venue and ground of IPL 2018
# Who:  Eden Gardens   name: best venue and ground of IPL 2018
#
#
# Ronaldo named most famous athlete again, Kohli ranked 11th
# Who:  Kohli   name: 11th
#
#
# India's WT20-winning manager named Zimbabwe's interim coach
# Who:  India 's WT20-winning manager   name: Zimbabwe 's interim coach
#
#
# Kohli named in Ireland T20 tour despite county on same dates
# Who:  None   name: None
#
#
# Tim Paine and Aaron Finch named Aus captains in ODI and T20I
# Who:  Tim Paine and Aaron Finch   name: T20I
#
#
# Messi wins case against firm named 'Massi' over name
# Who:  Messi   name: Massi
#
#
# Kohli named Wisden's leading cricketer for 2nd straight year
# Who:  Kohli   name: Wisden 's leading cricketer
#
#
# Smith sacked as Aus Test captain, Paine named replacement
# Who:  Paine   name: replacement
#
#
# Rahul Dravid named election icon for K'taka Assembly polls
# Who:  Rahul Dravid   name: election icon
#
#
# Bopanna shares pic of Bhatura stall named after Federer
# Who:  None   name: pic of Bhatura stall named after Federer
#
#
# Journo named Steve Smith wrongly slammed for ball-tampering
# Who:  Journo named Steve Smith   name: Steve Smith
#
#
# B'desh dressing room damaged after win over SL, player named
# Who:  None   name: None
#
#
# Virat Kohli named first Brand Ambassador for Uber India
# Who:  Virat Kohli   name: first Brand Ambassador for Uber India
#
#
# Player named Watt shown red as ref confuses name with 'What'
# Who:  ref   name: name
#
#
# 2-time IPL-winning captain Gambhir named Daredevils skipper
# Who:  2-time IPL - winning captain Gambhir   name: skipper
#
#
# Sunil Gavaskar named as Commissioner of T20 Mumbai League
# Who:  Sunil Gavaskar   name: None
#
#
# Dinesh Karthik named captain of Kolkata Knight Riders
# Who:  Dinesh Karthik   name: captain of Kolkata Knight Riders
#
#
# Indian wins gold, named best boxer of tournament in Bulgaria
# Who:  Indian   name: best boxer of tournament
#
#
# Shoaib Akhtar named brand ambassador of Pak Cricket Board
# Who:  Shoaib Akhtar   name: brand ambassador of Pak Cricket Board
#
#
# IPL's highest wicket-taker Malinga named MI's bowling mentor
# Who:  IPL 's highest wicket - taker Malinga   name: MI 's bowling mentor
#
#
# Galaxy 12.9 billion light-years away is named after Ronaldo
# Who:  Galaxy 12.9 billion light - years away   name: None
#
#
# Bumrah, Harmanpreet named in Forbes India 30 Under 30 list
# Who:  Harmanpreet   name: Under 30 list
#
#
# Raina named in India's 16-man squad for T20I series vs SA
# Who:  None   name: None
#
#
# Virat Kohli named ICC Cricketer of the Year
# Who:  Virat Kohli   name: ICC Cricketer of the Year
#
#
# Steve Smith named ICC Test Cricketer of the Year
# Who:  Steve Smith   name: ICC Test Cricketer of the Year
#
#
# 3 Indians in ICC Test Team of the Year, Kohli named captain
# Who:  Kohli   name: captain
#
#
# Chahal's 6/25 vs England named T20I Performance of the Year
# Who:  None   name: T20I Performance of the Year
#
#
# India's CT defeat vs Pak named ICC Fans' Moment of the Year
# Who:  India 's CT defeat vs Pak   name: ICC Fans ' Moment of the Year
#
#
# Manchester United legend Ryan Giggs named as Wales manager
# Who:  None   name: None
#
#
# Nadal, Federer named top seeds for Australian Open
# Who:  Federer   name: top seeds
#
#
# Stokes named in England's T20I squad for upcoming tri-series
# Who:  None   name: tri - series
#
#
# Lara named daughter after Sydney where he hit 277 as 1st ton
# Who:  he   name: 277 as 1st ton
#
#
# Liverpool's Mohamed Salah named African Footballer of 2017
# Who:  Liverpool 's Mohamed Salah   name: African Footballer of 2017

# %%
# Has to have "named"
# handles only verb form
# Out:
# 2
