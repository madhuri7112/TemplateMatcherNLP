# %%
import spacy
import nltk
from nltk.stem import WordNetLemmatizer

# %%
with open('die') as data_file:
        sentences = data_file.readlines()

# %%
nlp = spacy.load('en_core_web_lg')
wordnet_lemmatizer = WordNetLemmatizer()

# %%
SPACY_DEP_ROOT = "ROOT"
SPACY_DEP_NSUBJ = "nsubj"
SPACY_DEP_NSUBJ_PASS = "nsubjpass"
SPACY_DEP_DOBJ = "dobj"
SPACY_DEP_PREP = "prep"
SPACY_DEP_PREP_OBJ = "pobj"
SPACY_DEP_CCOMP = "ccomp"
SPACY_DEP_IND_OBJ_1 = "dative"
SPACY_DEP_IND_OBJ_2 = "iobj"

SPACY_TAG_PREP = "IN"
SPACY_TAG_NN = "NN"
SPACY_TAG_NNS = "NNS"
SPACY_TAG_NNP = "NNP"
SPACY_TAG_NNPS = "NNPS"
SPACY_TAG_JJ = "JJ"
SPACY_TAG_JJR = "JJR"
SPACY_TAG_JJS = "JJS"
SPACY_TAG_VB = "VB"
SPACY_TAG_VBD = "VBD"
SPACY_TAG_VBG = "VBG"
SPACY_TAG_VBN = "VBN"
SPACY_TAG_VBP = "VBP"
SPACY_TAG_VBZ = "VBZ"

PREP_FOR = "for"
PREP_TO = "to"
PREP_FROM = "from"
PREP_OVER = "over"
PREP_UNTIL = "until"
PREP_OF = "of"
PREP_AT = "at"
PREP_IN = "in"
PREP_ON = "on"
PREP_NEAR = "near"

def getSubTreeString(token):
    if not token:
        return ""
    return ' '.join([str(token1.text) for token1 in list(token.subtree)])

def getHeadOfSentence(sentence):

    doc = nlp(str(sentence))
    head = None
    for token in doc:
        if token.dep_ == SPACY_DEP_ROOT:
            #print ("head",sentence, token.text)
            head = token
            
    return head  

def printTree(sentence):
    doc = nlp(str(sentence))
 
    for token in doc:
        print("{5}: {0}/{1} <--{2}-- {3}/{4} > {6};  type {7}".format(
           token.text, token.tag_, token.dep_, token.head.text, token.head.tag_,token.i,token.head.i, token.ent_id_))
        
        print(list(token.subtree))
        print ('**********')
        
def printEntities(sentence):
    doc = nlp(str(sentence))
    for ent in doc.ents:
        print(ent.text, ent.label_)
        
def findSubjectOfToken(sentence, targetToken):
    doc = nlp(sentence)
    for token in doc:
        if token.head.i == targetToken.i and  token.dep_ in [SPACY_DEP_NSUBJ]:
            return token
    
    return None
        
def findPrepsAttachedToToken(sentence, targetToken):
    doc = nlp(sentence)
    associatedPrepositionIds = {}
    for token in doc:
        if token.head.i == targetToken.i and token.tag_ == SPACY_TAG_PREP:
            associatedPrepositionIds[token.i] = token
    
    return associatedPrepositionIds

# %%
def parse(sentence):
    rootWord = getHeadOfSentence(sentence)
    whoDied = None
    whereDied = None
    whenDied = None
    age = None
    reason = None
    
    whoDied = getSubTreeString(findSubjectOfToken(sentence, rootWord))
    preps = findPrepsAttachedToToken(sentence, rootWord)
    
    for prepId, prepToken in preps.items():
        if prepToken.text == PREP_OF:
            reason = getSubTreeString(prepToken)
        
        elif prepToken.text in [PREP_AT, PREP_NEAR, PREP_IN]:
            subTreeText = getSubTreeString(prepToken)
            if 'age'  not in subTreeText:
                whereDied = subTreeText
            else:
                age = subTreeText
        elif prepToken.text == PREP_ON:
            whenDied = getSubTreeString(prepToken)
    print(sentence)            
    print ("Who: " ,whoDied, "where: ", whereDied, "whenDIed: ", whenDied, "age: ", age, "reason: ", reason)
    print("\n")

# %%
for sentence in sentences:
    sentence.replace('\n','')
    parse(sentence)
# Out:
# 49-year-old boxer dies days after knockout in title fight
#
# Who:  49-year - old boxer where:  in title whenDIed:  None age:  None reason:  None
#
#
# Miss being there, kill it: Hardik Pandya on brother Krunal's debut
#
# Who:   where:  None whenDIed:  None age:  None reason:  None
#
#
# Leicester City's billionaire Thai owner dies in helicopter crash
#
# Who:  Leicester City 's billionaire Thai owner where:  in helicopter crash
#  whenDIed:  None age:  None reason:  None
#
#
# Former boxing champion dies after being hit by car in Italy
#
# Who:  Former boxing champion where:  None whenDIed:  None age:  None reason:  None
#
#
# You die of shame: Coach shouted at Tajinderpal before gold win
#
# Who:  Coach where:  at Tajinderpal whenDIed:  None age:  None reason:  None
#
#
# E-sports gamer kills self after killing 2 at gaming event
#
# Who:  E - sports gamer where:  None whenDIed:  None age:  None reason:  None
#
#
# Nepalese worker dies at 2022 World Cup stadium site in Qatar
#
# Who:  Nepalese worker where:  at 2022 World Cup stadium site in Qatar
#  whenDIed:  None age:  None reason:  None
#
#
# No one will die: Dean Jones on India's 2 ODIs in 2 days
#
# Who:  No one Dean Jones on India 's 2 ODIs where:  in 2 days
#  whenDIed:  None age:  None reason:  None
#
#
# Ex-400m hurdles world champ dies in car crash aged 28
#
# Who:   where:  None whenDIed:  None age:  None reason:  None
#
#
# 2 Hyderabad kids die after shed collapses in Karate class
#
# Who:  2 Hyderabad kids where:  None whenDIed:  None age:  None reason:  None
#
#
# Former Olympic skiing gold winner dies in jet-ski accident
#
# Who:  Former Olympic skiing gold winner where:  in jet - ski accident
#  whenDIed:  None age:  None reason:  None
#
#
# Ex-WWE wrestler Brian Lawler dies after hanging self in jail
#
# Who:  Ex - WWE wrestler Brian Lawler where:  None whenDIed:  None age:  None reason:  None
#
#
# SA squash coach dies after collapsing on road in Chennai
#
# Who:  SA squash coach where:  None whenDIed:  None age:  None reason:  None
#
#
# We kill them, Messi or no Messi: Pogba before Argentina game
#
# Who:  We where:  None whenDIed:  None age:  None reason:  None
#
#
# I feared Serena would die after giving birth: Husband Alexis
#
# Who:   where:  None whenDIed:  None age:  None reason:  None
#
#
# Messi fan from Kolkata dies trying to imitate player's move
#
# Who:  Messi fan from Kolkata where:  None whenDIed:  None age:  None reason:  None
#
#
# Indian fan dies in car crash in Russia near World Cup venue
#
# Who:  Indian fan where:  in car crash in Russia whenDIed:  None age:  None reason:  None
#
#
# Woman celebrating WC win dies after falling on wine glass
#
# Who:  Woman celebrating WC win where:  None whenDIed:  None age:  None reason:  None
#
#
# Football expert dies of shock as Egypt lose to Saudi in WC
#
# Who:  Football expert where:  None whenDIed:  None age:  None reason:  of shock
#
#
# Lightning kills 21-year-old aspiring cricketer in Kolkata
#
# Who:  Lightning where:  None whenDIed:  None age:  None reason:  None
#
#
# Watson in IPL final proved age doesn't kill passion: Gambhir
#
# Who:   where:  None whenDIed:  None age:  None reason:  None
#
#
# Blasts kills eight people at cricket match in Afghanistan
#
# Who:  Blasts where:  None whenDIed:  None age:  None reason:  None
#
#
# Pak hockey legend who wanted heart transplant in India dies
#
# Who:  Pak hockey legend who wanted heart transplant in India where:  None whenDIed:  None age:  None reason:  None
#
#
# MasterChef contestant dies after collapse at London Marathon
#
# Who:  MasterChef contestant where:  None whenDIed:  None age:  None reason:  None
#
#
# 23-year-old cyclist suffers cardiac arrest during race, dies
#
# Who:  23-year - old cyclist where:  None whenDIed:  None age:  None reason:  None
#
#
# 20-year-old Indian wrestler dies after breaking neck in bout
#
# Who:  20-year - old Indian wrestler where:  None whenDIed:  None age:  None reason:  None
#
#
# 26-year-old basketball player dies after collapsing mid-game
#
# Who:  26-year - old basketball player where:  None whenDIed:  None age:  None reason:  None
#
#
# 25-yr-old footballer dies on field after ball hits his chest
#
# Who:  25-yr - old footballer where:  None whenDIed:  on field age:  None reason:  None
#
#
# Italian football club captain Astori dies in his sleep at 31
#
# Who:  Italian football club captain Astori where:  at 31
#  whenDIed:  None age:  None reason:  None
#
#
# First man to run a mile in under 4 minutes dies at 88
#
# Who:  First man to run a mile in under 4 minutes where:  at 88
#  whenDIed:  None age:  None reason:  None
#
#
# 31-year-old boxer dies after injury in 10-round win
#
# Who:  31-year - old boxer where:  None whenDIed:  None age:  None reason:  None
#
#
# Man dies of heart attack while playing cricket in Hyderabad
#
# Who:  Man where:  None whenDIed:  None age:  None reason:  of heart attack
#
#
# TN cricketer dies after cars collide while racing on highway
#
# Who:  TN cricketer where:  None whenDIed:  None age:  None reason:  None
#
#
# Racing legend Dan Gurney dies after pneumonia complications
#
# Who:  Racing legend Dan Gurney where:  None whenDIed:  None age:  None reason:  None
#
#
# India's Asiad medalist wrestler dies in road accident
#
# Who:  India 's Asiad medalist wrestler where:  in road accident
#  whenDIed:  None age:  None reason:  None
#
#
# Man, who set himself on fire after Kohli got out on 5, dies
#
# Who:  Man , who set himself on fire after Kohli got out on 5 where:  None whenDIed:  None age:  None reason:  None
#
#
# Indian powerlifting world champion dies following car crash
#
# Who:  Indian powerlifting world champion where:  None whenDIed:  None age:  None reason:  None
#
#
# 4 powerlifters die in road accident near Delhi
#
# Who:  4 powerlifters where:  in road accident near Delhi
#  whenDIed:  None age:  None reason:  None
#
#
# 62-year-old man dies of heart attack at Vadodara marathon
#
# Who:  62-year - old man where:  None whenDIed:  None age:  None reason:  of heart attack at Vadodara marathon
#
#
#
# Our cricket won't die if we don't play with India: Miandad
#
# Who:  Our cricket where:  None whenDIed:  None age:  None reason:  None
#
#
# Rahane's father arrested after car runs over, kills woman
#
# Who:  Rahane 's father where:  None whenDIed:  None age:  None reason:  None
#
#
# Rahane's father granted bail after car accident kills woman
#
# Who:  Rahane 's father where:  None whenDIed:  None age:  None reason:  None
#
#
# Chinese rooftop climber dies in 62-storey fall
#
# Who:  Chinese rooftop climber where:  in 62-storey fall
#  whenDIed:  None age:  None reason:  None

# %%
sentence = "49 year old boxer dies days after knockout in title fight"
sentence = "50 year old Cricket player John died of tumor in London"
#sentence = "John dies of Tumor in London on saturday at an age of 50 "
printTree(sentence)
printEntities(sentence)
parse(sentence)
# Out:
# 0: 50/CD <--nummod-- year/NN > 1;  type
# [50]
# **********
# 1: year/NN <--npadvmod-- old/JJ > 2;  type
# [50, year]
# **********
# 2: old/JJ <--amod-- player/NN > 4;  type
# [50, year, old]
# **********
# 3: Cricket/NNP <--compound-- player/NN > 4;  type
# [Cricket]
# **********
# 4: player/NN <--nsubj-- died/VBD > 6;  type
# [50, year, old, Cricket, player, John]
# **********
# 5: John/NNP <--appos-- player/NN > 4;  type
# [John]
# **********
# 6: died/VBD <--ROOT-- died/VBD > 6;  type
# [50, year, old, Cricket, player, John, died, of, tumor, in, London]
# **********
# 7: of/IN <--prep-- died/VBD > 6;  type
# [of, tumor]
# **********
# 8: tumor/NN <--pobj-- of/IN > 7;  type
# [tumor]
# **********
# 9: in/IN <--prep-- died/VBD > 6;  type
# [in, London]
# **********
# 10: London/NNP <--pobj-- in/IN > 9;  type
# [London]
# **********
# 50 year old DATE
# John PERSON
# London GPE
# 50 year old Cricket player John died of tumor in London
# Who:  50 year old Cricket player John where:  in London whenDIed:  None age:  None reason:  of tumor

# %%
#sentence = "49 year old boxer dies days after knockout in title fight"
#sentence = "50 year old Cricket player John died of tumor at St Marks Hospital"
#sentence = "John dies of Tumor in London on saturday at an age of 50 "

# Problem:  in <car crash>.  in <hospital> -- Differnetiate??
